# %%
import pandas as pd

# %%
lab = pd.read_csv("labcount.csv")
drug = pd.read_csv("drugcount.csv")

# %%
def edit_str(str):
    return int(str.split("-")[0])+1

# %%
lab.head()
# Out:
#    MemberID Year         DSFS LabCount
# 0  69258001   Y3  2- 3 months        1
# 1  10143167   Y1   0- 1 month        2
# 2   1054357   Y1   0- 1 month        6
# 3  56583841   Y3  6- 7 months        4
# 4  70967047   Y2   0- 1 month        2

# %%
drug.head()
# Out:
#    MemberID Year          DSFS DrugCount
# 0  48925661   Y2   9-10 months        7+
# 1  90764620   Y3   8- 9 months         3
# 2  61221204   Y1   2- 3 months         1
# 3  63628544   Y3   1- 2 months         1
# 4  46949606   Y2  10-11 months         3

# %%
lab["DSFS"] = lab["DSFS"].apply(edit_str)
drug["DSFS"] = drug["DSFS"].apply(edit_str)

# %% [markdown]
# Thay thế các giá trị của cột DSFS từ string thành interger, lấy số lớn hơn giữa 2 số

# %%
def edit_count(str):
    str = str.replace("+","")
    return int(str)

# %%
lab["LabCount"] = lab["LabCount"].apply(edit_count)
drug["DrugCount"] = drug["DrugCount"].apply(edit_count)

# %% [markdown]
# Chuyển tất cả giá trị trong cột LabCount và DrugCount thành interger

# %%
lab_Y1 = lab[lab["Year"] == "Y1"]
lab_Y2 = lab[lab["Year"] == "Y2"]
lab_Y3 = lab[lab["Year"] == "Y3"]

# %%
drug_Y1 = drug[drug["Year"] == "Y1"]
drug_Y2 = drug[drug["Year"] == "Y2"]
drug_Y3 = drug[drug["Year"] == "Y3"]

# %% [markdown]
# tách dataframe theo các năm Y1, Y2, Y3

# %%
lab_Y1.head()
# Out:
#     MemberID Year  DSFS  LabCount
# 1   10143167   Y1     1         2
# 2    1054357   Y1     1         6
# 26  43367747   Y1     1        10
# 27   4317556   Y1     1         3
# 28  12608801   Y1     8         2

# %%
lab_Y1 = lab_Y1.groupby("MemberID").sum()
lab_Y1.reset_index(inplace = True)

# %%
drug_Y1 = drug_Y1.groupby("MemberID").sum()
drug_Y1.reset_index(inplace = True)

# %% [markdown]
# Lấy tổng giá trị các cột DSFS và DrugCount/LabCount với các giá trị có cùng MemberID

# %%
df = pd.merge(lab_Y1, drug_Y1, on="MemberID", how="outer")

# %% [markdown]
# Merge 2 df lại theo cùng MemberID

# %%
df.head()
# Out:
#    MemberID  DSFS_x  LabCount  DSFS_y  DrugCount
# 0       210     2.0       2.0    10.0        5.0
# 1      3889     1.0      10.0    60.0       30.0
# 2     11951     5.0       3.0     NaN        NaN
# 3     14661     1.0       2.0     1.0        1.0
# 4     14778     1.0       2.0    15.0        6.0

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# Điền giá trị 0 vào những chỗ bị thiếu

# %%
df.head()
# Out:
#    MemberID  DSFS_x  LabCount  DSFS_y  DrugCount
# 0       210     2.0       2.0    10.0        5.0
# 1      3889     1.0      10.0    60.0       30.0
# 2     11951     5.0       3.0     0.0        0.0
# 3     14661     1.0       2.0     1.0        1.0
# 4     14778     1.0       2.0    15.0        6.0

# %%
df.rename(index=str, columns={"DSFS_x": "DSFS_Lab", "DSFS_y": "DSFS_Drug"})
# Out:
#        MemberID  DSFS_Lab  LabCount  DSFS_Drug  DrugCount
# 0           210       2.0       2.0       10.0        5.0
# 1          3889       1.0      10.0       60.0       30.0
# 2         11951       5.0       3.0        0.0        0.0
# 3         14661       1.0       2.0        1.0        1.0
# 4         14778       1.0       2.0       15.0        6.0
# 5         17249       1.0       2.0        0.0        0.0
# 6         18190       6.0       6.0       48.0       15.0
# 7         18333       3.0       6.0       42.0       10.0
# 8         18514       1.0       5.0        0.0        0.0
# 9         20072       7.0       1.0       33.0       13.0
# 10        20269       1.0       4.0        0.0        0.0
# 11        20482      66.0      17.0        0.0        0.0
# 12        21207      10.0      16.0       37.0       27.0
# 13        23328       9.0       4.0        0.0        0.0
# 14        27686       1.0       4.0        0.0        0.0
# ...

# %%
df.to_csv("lab_drug.csv", sep='\t')
