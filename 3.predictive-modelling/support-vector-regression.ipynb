# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import pandas as pd
import math
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_csv('../1.data-preparation/new-data/data_Y1.csv')
data.describe()
# Out:
#            MemberID  ClaimsTruncated        TARGET  trainset        age_05  \
# count  7.603700e+04     76037.000000  76037.000000   76037.0  76037.000000
# mean   4.994795e+07         0.052225      0.467102       1.0      0.085866
# std    2.890149e+07         0.222481      1.612204       0.0      0.280168
# min    2.100000e+02         0.000000      0.000000       1.0      0.000000
# 25%    2.483922e+07         0.000000      0.000000       1.0      0.000000
# 50%    4.990758e+07         0.000000      0.000000       1.0      0.000000
# 75%    7.510115e+07         0.000000      0.000000       1.0      0.000000
# max    9.999863e+07         1.000000     15.000000       1.0      1.000000
#
#              age_15        age_25        age_35        age_45        age_55  \
# count  76037.000000  76037.000000  76037.000000  76037.000000  76037.000000
# mean       0.090824      0.059405      0.096098      0.132935      0.112366
# std        0.287361      0.236383      0.294727      0.339507      0.315819
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            ...       drugCount_max  drugCount_min  drugCount_ave  \
# count      ...        76037.000000   76037.000000   76037.000000
# mean       ...            2.175033       0.968765       1.511600
# std        ...            2.243436       1.046544       1.536634
# min        ...            0.000000       0.000000       0.000000
# 25%        ...            0.000000       0.000000       0.000000
# 50%        ...            2.000000       1.000000       1.200000
# 75%        ...            4.000000       1.000000       2.285714
# max        ...            7.000000       7.000000       7.000000
#
#        drugcount_months  labCount_max  labCount_min  labCount_ave  \
# count      76037.000000  76037.000000  76037.000000  76037.000000
# mean           3.703697      3.758749      2.178216      2.885066
# std            4.089940      3.434990      2.533432      2.696510
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.000000      0.000000      0.000000
# 50%            2.000000      3.000000      1.000000      2.600000
# 75%            7.000000      6.000000      3.000000      4.800000
# max           12.000000     10.000000     10.000000     10.000000
#
#        labcount_months       labNull      drugNull
# count     76037.000000  76037.000000  76037.000000
# mean          1.580296      0.299999      0.344569
# std           1.814171      0.458260      0.475231
# min           0.000000      0.000000      0.000000
# 25%           0.000000      0.000000      0.000000
# 50%           1.000000      0.000000      0.000000
# 75%           2.000000      1.000000      1.000000
# max          12.000000      1.000000      1.000000
#
# [8 rows x 142 columns]

# %%
data.drop("MemberID", axis = 1, inplace = True)
data.drop("Year", axis = 1, inplace = True)

X = data.loc[:, data.columns != 'TARGET']
y = data['TARGET']
y.describe()

from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler = StandardScaler().fit(X)
X = scaler.transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
def eval(model, X_test, y_test):
    pred_y = model.predict(X_test) # your predicted y values
    pred_y = pred_y.clip(min=0)
    pred_y = pred_y.clip(max=15)
    pred_y = pred_y.astype(int)
    # The root mean square logarithmic error
    msle = np.mean( (np.log(pred_y + 1) - np.log(y_test + 1)) ** 2)
    rmsle = math.sqrt(msle)
    
    print ("RMSLE: %.4f" % rmsle)
    from sklearn.metrics import r2_score
    r2 = r2_score(pred_y, y_test)
    print ("R2 value: %.4f" % r2)

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weights = np.array(class_weights).tolist()
d = {}

for idx,item in enumerate(class_weights):
    d[idx] = item
d
# Out:
# {0: 0.07394168574540443,
#  1: 0.9824461015948022,
#  2: 2.0087937801932365,
#  3: 3.25814152791381,
#  4: 4.913681683899557,
#  5: 8.31640625,
#  6: 12.648526615969581,
#  7: 18.794138418079097,
#  8: 25.393606870229007,
#  9: 33.265625,
#  10: 46.85299295774648,
#  11: 60.48295454545455,
#  12: 70.77792553191489,
#  13: 75.60369318181819,
#  14: 110.88541666666667,
#  15: 18.68855337078652}

# %%
from sklearn import svm

model_all = svm.SVR(epsilon =0.02,verbose=1)
model_all.fit(X_train, y_train)
eval(model_all, X_test, y_test)
# Out:
# [LibSVM]

# %%
data_submit = pd.read_csv('../1.data-preparation/new-data/data_Y2.csv')
data_submit.describe()
# Out:
#            MemberID  ClaimsTruncated        TARGET  trainset        age_05  \
# count  7.143500e+04     71435.000000  71435.000000   71435.0  71435.000000
# mean   4.993986e+07         0.056611      0.437895       1.0      0.088108
# std    2.894077e+07         0.231099      1.531780       0.0      0.283454
# min    4.000000e+00         0.000000      0.000000       1.0      0.000000
# 25%    2.477813e+07         0.000000      0.000000       1.0      0.000000
# 50%    4.995379e+07         0.000000      0.000000       1.0      0.000000
# 75%    7.521986e+07         0.000000      0.000000       1.0      0.000000
# max    9.999882e+07         1.000000     15.000000       1.0      1.000000
#
#              age_15        age_25        age_35        age_45        age_55  \
# count  71435.000000  71435.000000  71435.000000  71435.000000  71435.000000
# mean       0.085364      0.057213      0.096563      0.136474      0.116232
# std        0.279425      0.232251      0.295364      0.343293      0.320505
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            ...       drugCount_max  drugCount_min  drugCount_ave  \
# count      ...        71435.000000   71435.000000   71435.000000
# mean       ...            2.207475       0.948695       1.516412
# std        ...            2.281410       1.040350       1.559578
# min        ...            0.000000       0.000000       0.000000
# 25%        ...            0.000000       0.000000       0.000000
# 50%        ...            2.000000       1.000000       1.222222
# 75%        ...            4.000000       1.000000       2.333333
# max        ...            7.000000       7.000000       7.000000
#
#        drugcount_months  labCount_max  labCount_min  labCount_ave  \
# count      71435.000000  71435.000000  71435.000000  71435.000000
# mean           3.864030      3.879919      2.180024      2.937653
# std            4.210155      3.421071      2.471471      2.640371
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.000000      0.000000      0.000000
# 50%            2.000000      4.000000      1.000000      3.000000
# 75%            8.000000      7.000000      3.000000      4.800000
# max           12.000000     10.000000     10.000000     10.000000
#
#        labcount_months       labNull      drugNull
# count     71435.000000  71435.000000  71435.000000
# mean          1.713670      0.282313      0.353090
# std           1.975234      0.450128      0.477934
# min           0.000000      0.000000      0.000000
# 25%           0.000000      0.000000      0.000000
# 50%           1.000000      0.000000      0.000000
# 75%           2.000000      1.000000      1.000000
# max          12.000000      1.000000      1.000000
#
# [8 rows x 142 columns]

# %%
data_submit.drop("MemberID", axis = 1, inplace = True)
data_submit.drop("Year", axis = 1, inplace = True)

y_submit = data_submit['TARGET']
X_submit = data_submit.loc[:, data_submit.columns != 'TARGET']
y_submit.head()
# Out:
# 0    1.0
# 1    1.0
# 2    0.0
# 3    0.0
# 4    0.0
# Name: TARGET, dtype: float64

# %%
X_submit = scaler.transform(X_submit)

# %%
eval(model_all, X_submit, y_submit)
# Out:
# RMSLE: 0.5063
# R2 value: -1104.3886

# %%
data = pd.read_csv('../1.data-preparation/new-data/data_Y2.csv')
pred_y = model_all.predict(X_submit)

submission = pd.DataFrame()
submission['MemberID'] = data['MemberID']
pred_y = pred_y.clip(min=0)
pred_y = pred_y.clip(max=15)
submission['DIH'] = pred_y.astype(int)
submission.head()
submission.groupby(['DIH']).size()
# Out:
# DIH
# -1        1
#  0    71363
#  1       56
#  2       14
#  3        1
# dtype: int64
